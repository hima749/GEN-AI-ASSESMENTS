# %%
# !pip install langchain

from langchain_core.prompts import PromptTemplate, ChatPromptTemplate
# Out:
# Requirement already satisfied: langchain in c:\users\himan\anaconda3\lib\site-packages (1.2.15)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.10 in c:\users\himan\anaconda3\lib\site-packages (from langchain) (1.2.28)
# Requirement already satisfied: langgraph<1.2.0,>=1.1.5 in c:\users\himan\anaconda3\lib\site-packages (from langchain) (1.1.6)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\himan\anaconda3\lib\site-packages (from langchain) (2.12.4)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\himan\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\himan\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (0.7.29)
# Requirement already satisfied: packaging>=23.2.0 in c:\users\himan\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (25.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\himan\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\himan\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (9.1.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\himan\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\himan\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (0.14.1)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\himan\anaconda3\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.10->langchain) (3.0.0)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=2.1.0 in c:\users\himan\anaconda3\lib\site-packages (from langgraph<1.2.0,>=1.1.5->langchain) (4.0.1)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.9 in c:\users\himan\anaconda3\lib\site-packages (from langgraph<1.2.0,>=1.1.5->langchain) (1.0.9)
# Requirement already satisfied: langgraph-sdk<0.4.0,>=0.3.0 in c:\users\himan\anaconda3\lib\site-packages (from langgraph<1.2.0,>=1.1.5->langchain) (0.3.13)
# Requirement already satisfied: xxhash>=3.5.0 in c:\users\himan\anaconda3\lib\site-packages (from langgraph<1.2.0,>=1.1.5->langchain) (3.6.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in c:\users\himan\anaconda3\lib\site-packages (from langgraph-checkpoint<5.0.0,>=2.1.0->langgraph<1.2.0,>=1.1.5->langchain) (1.12.2)
# Requirement already satisfied: httpx>=0.25.2 in c:\users\himan\anaconda3\lib\site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (0.28.1)
# Requirement already satisfied: orjson>=3.11.5 in c:\users\himan\anaconda3\lib\site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (3.11.8)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\himan\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\users\himan\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\himan\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (0.24.0)
# Requirement already satisfied: anyio in c:\users\himan\anaconda3\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (4.10.0)
# Requirement already satisfied: certifi in c:\users\himan\anaconda3\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in c:\users\himan\anaconda3\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (1.0.9)
# Requirement already satisfied: idna in c:\users\himan\anaconda3\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\users\himan\anaconda3\lib\site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\himan\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.6.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\himan\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\himan\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\himan\anaconda3\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\himan\anaconda3\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (2.5.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\himan\anaconda3\lib\site-packages (from anyio->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (1.3.0)

# %%
# Task 1: Basic PromptTemplate

template_1 = PromptTemplate(
    input_variables=["topic"],
    template="Explain {topic} in simple terms for beginners"
)

# Test
output_1 = template_1.format(topic="Artificial Intelligence")
print(output_1)
# Out:
# Explain Artificial Intelligence in simple terms for beginners

# %%
# Task 2: Multi-input template

multi_input_template = PromptTemplate(
    input_variables=["topic", "audience", "tone"],
    template="Explain {topic} for {audience} in a {tone} tone"
)

# Test cases
print(multi_input_template.format(topic="AI", audience="beginners", tone="friendly"))
print(multi_input_template.format(topic="Python", audience="kids", tone="fun"))
print(multi_input_template.format(topic="Deep Learning", audience="engineers", tone="technical"))
# Out:
# Explain AI for beginners in a friendly tone
# Explain Python for kids in a fun tone
# Explain Deep Learning for engineers in a technical tone

# %%
# Task 3: Multiple templates

teaching_template = PromptTemplate(
    input_variables=["topic"],
    template="Explain {topic} clearly step by step"
)

interview_template = PromptTemplate(
    input_variables=["topic"],
    template="Ask 3 interview questions about {topic}"
)

story_template = PromptTemplate(
    input_variables=["topic"],
    template="Explain {topic} as a story"
)

# Run all
topic = "Machine Learning"

print(teaching_template.format(topic=topic))
print(interview_template.format(topic=topic))
print(story_template.format(topic=topic))
# Out:
# Explain Machine Learning clearly step by step
# Ask 3 interview questions about Machine Learning
# Explain Machine Learning as a story

# %%
# Task 4: Chat Prompt System

def get_chat_prompt(role, topic):
    
    if role == "teacher":
        system_message = "You are a helpful teacher."
    elif role == "interviewer":
        system_message = "You are a strict interviewer."
    elif role == "motivator":
        system_message = "You are an inspiring motivator."
    else:
        system_message = "You are a helpful assistant."
    
    chat_template = ChatPromptTemplate.from_messages([
        ("system", system_message),
        ("user", "Talk about {topic}")
    ])
    
    return chat_template.format(topic=topic)

# Test
print(get_chat_prompt("teacher", "Neural Networks"))
# Out:
# System: You are a helpful teacher.
# Human: Talk about Neural Networks

# %%
# Task 5: Input validation

def validate_inputs(audience, tone):
    
    valid_audience = ["beginner", "intermediate", "expert"]
    valid_tone = ["formal", "casual", "fun"]
    
    if audience not in valid_audience:
        print("Invalid audience! Setting default = beginner")
        audience = "beginner"
    
    if tone not in valid_tone:
        print("Invalid tone! Setting default = formal")
        tone = "formal"
    
    return audience, tone

# Test
print(validate_inputs("kids", "cool"))
# Out:
# Invalid audience! Setting default = beginner
# Invalid tone! Setting default = formal
# ('beginner', 'formal')

# %%
# Task 6: Prompt Generator

def generate_prompt(topic, audience, tone, style):
    
    audience, tone = validate_inputs(audience, tone)
    
    if style == "teaching":
        template = "Explain {topic} for {audience} in a {tone} tone step by step"
        
    elif style == "interview":
        template = "Ask interview questions about {topic} for {audience} in a {tone} tone"
        
    elif style == "storytelling":
        template = "Explain {topic} for {audience} in a {tone} storytelling style"
        
    else:
        template = "Explain {topic} for {audience} in a {tone} tone"
    
    prompt = PromptTemplate(
        input_variables=["topic", "audience", "tone"],
        template=template
    )
    
    return prompt.format(topic=topic, audience=audience, tone=tone)

# Test
print(generate_prompt("Neural Networks", "beginner", "fun", "storytelling"))
# Out:
# Explain Neural Networks for beginner in a fun storytelling style

# %%
# Task 7: One template reused multiple times

reuse_template = PromptTemplate(
    input_variables=["topic", "audience"],
    template="Explain {topic} for {audience}"
)

# Different inputs
inputs = [
    ("AI", "beginners"),
    ("Python", "students"),
    ("Data Science", "analysts"),
    ("Deep Learning", "researchers"),
    ("Biotechnology", "graduates")
]

for topic, audience in inputs:
    print(reuse_template.format(topic=topic, audience=audience))
# Out:
# Explain AI for beginners
# Explain Python for students
# Explain Data Science for analysts
# Explain Deep Learning for researchers
# Explain Biotechnology for graduates
